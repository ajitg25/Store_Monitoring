# %%
import pandas as pd
import numpy as np

# %%
active_data = pd.read_csv('store status.csv')
business_hour = pd.read_csv('Menu hours.csv')
timezone = pd.read_csv('timezone.csv')

# %%
active_data
# Out:
#                     store_id    status                   timestamp_utc
# 0        8419537941919820732    active  2023-01-22 12:09:39.388884 UTC
# 1          54515546588432327    active  2023-01-24 09:06:42.605777 UTC
# 2        8377465688456570187    active  2023-01-24 09:07:26.441407 UTC
# 3        5955337179846162144    active  2023-01-24 09:08:07.634899 UTC
# 4        1169347689335808384    active  2023-01-24 09:08:18.436854 UTC
# ...                      ...       ...                             ...
# 1822075  9103029069217106077  inactive  2023-01-20 09:02:21.705125 UTC
# 1822076  5532343280896549215  inactive  2023-01-21 02:03:58.311087 UTC
# 1822077  3794430814933142786  inactive  2023-01-21 04:04:20.916254 UTC
# 1822078  4192592653801050907  inactive  2023-01-21 15:11:50.902575 UTC
# 1822079  3846497499881872792  inactive  2023-01-21 08:04:26.177456 UTC
#
# [1822080 rows x 3 columns]

# %%
active_data.index.name = 'foo'
active_data
# Out:
#                     store_id    status                   timestamp_utc
# foo
# 0        8419537941919820732    active  2023-01-22 12:09:39.388884 UTC
# 1          54515546588432327    active  2023-01-24 09:06:42.605777 UTC
# 2        8377465688456570187    active  2023-01-24 09:07:26.441407 UTC
# 3        5955337179846162144    active  2023-01-24 09:08:07.634899 UTC
# 4        1169347689335808384    active  2023-01-24 09:08:18.436854 UTC
# ...                      ...       ...                             ...
# 1822075  9103029069217106077  inactive  2023-01-20 09:02:21.705125 UTC
# 1822076  5532343280896549215  inactive  2023-01-21 02:03:58.311087 UTC
# 1822077  3794430814933142786  inactive  2023-01-21 04:04:20.916254 UTC
# 1822078  4192592653801050907  inactive  2023-01-21 15:11:50.902575 UTC
# 1822079  3846497499881872792  inactive  2023-01-21 08:04:26.177456 UTC
#
# [1822080 rows x 3 columns]

# %%
 active_data.rename_axis('foo').rename_axis("ind", axis="columns")
# Out:
# ind                 store_id    status                   timestamp_utc
# foo
# 0        8419537941919820732    active  2023-01-22 12:09:39.388884 UTC
# 1          54515546588432327    active  2023-01-24 09:06:42.605777 UTC
# 2        8377465688456570187    active  2023-01-24 09:07:26.441407 UTC
# 3        5955337179846162144    active  2023-01-24 09:08:07.634899 UTC
# 4        1169347689335808384    active  2023-01-24 09:08:18.436854 UTC
# ...                      ...       ...                             ...
# 1822075  9103029069217106077  inactive  2023-01-20 09:02:21.705125 UTC
# 1822076  5532343280896549215  inactive  2023-01-21 02:03:58.311087 UTC
# 1822077  3794430814933142786  inactive  2023-01-21 04:04:20.916254 UTC
# 1822078  4192592653801050907  inactive  2023-01-21 15:11:50.902575 UTC
# 1822079  3846497499881872792  inactive  2023-01-21 08:04:26.177456 UTC
#
# [1822080 rows x 3 columns]

# %%
active_data['ind']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\miniconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\miniconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ind'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
active_data.columns
# Out:
# Index(['store_id', 'status', 'timestamp_utc'], dtype='object')

# %%
active_data.isnull().sum()
# Out:
# store_id         0
# status           0
# timestamp_utc    0
# dtype: int64

# %%
active_data.shape
# Out:
# (1822080, 3)

# %%
active_data.dtypes
# Out:
# store_id          int64
# status           object
# timestamp_utc    object
# dtype: object

# %%
distinct_count = active_data['store_id'].value_counts()
distinct_count
# Out:
# 2311272071941344516    381
# 3345190510668585029    381
# 2994760733762859774    381
# 8444136742823051302    280
# 2102740864792234278    280
#                       ...
# 5693945648443136681     29
# 1217505942626861817      5
# 3820046627859013224      5
# 9018735632573947773      2
# 4542926605533674949      1
# Name: store_id, Length: 14092, dtype: int64

# %%
distinct_count[2994760733762859774]
# Out:
# 381

# %%
storID_Active = list(distinct_count.keys())

# %%
business_hour
# Out:
#                   store_id  day start_time_local end_time_local
# 0      1481966498820158979    4         00:00:00       00:10:00
# 1      1481966498820158979    2         00:00:00       00:10:00
# 2      1481966498820158979    0         00:00:00       00:10:00
# 3      1481966498820158979    1         00:00:00       00:10:00
# 4      1481966498820158979    5         00:00:00       00:10:00
# ...                    ...  ...              ...            ...
# 86193  1774428314218854399    4         00:00:00       23:59:59
# 86194  1774428314218854399    6         00:00:00       23:59:59
# 86195  1774428314218854399    3         00:00:00       23:59:59
# 86196  1774428314218854399    2         00:00:00       23:59:59
# 86197  1774428314218854399    1         00:00:00       23:59:59
#
# [86198 rows x 4 columns]

# %%
business_hour.dtypes
# Out:
# store_id             int64
# day                  int64
# start_time_local    object
# end_time_local      object
# dtype: object

# %%
business_hour.shape
# Out:
# (86198, 4)

# %%
business_hour.isnull().sum()
# Out:
# store_id            0
# day                 0
# start_time_local    0
# end_time_local      0
# dtype: int64

# %%
distinct_count = business_hour['store_id'].value_counts()
distinct_count
# Out:
# 778281888660867776     21
# 5785297779221538030    21
# 5301149089444945306    21
# 1472400125885919118    21
# 1176400014944170417    21
#                        ..
# 7684223852601174802     1
# 5711387831194927509     1
# 1424913054868561500     1
# 5437414992872782794     1
# 4520392672582664114     1
# Name: store_id, Length: 11116, dtype: int64

# %%
storID_Business = list(distinct_count.keys())
storID_Business
# Out:
# [778281888660867776,
#  5785297779221538030,
#  5301149089444945306,
#  1472400125885919118,
#  1176400014944170417,
#  3334248282862149533,
#  1600782661161589441,
#  6767755065226857745,
#  2983629168699704615,
#  152977603852070841,
#  2372720923498181697,
#  3579943253134828972,
#  3324789750983437691,
#  8698418252385094522,
#  986260775909687274,
#  6592609963459366848,
#  4416543351830401373,
#  6404334467189111912,
#  8971898130329485838,
#  2734353441360432503,
#  221031507125373830,
#  2826673752016981039,
#  933257307636497177,
#  5839057466366086215,
#  2105374776959745631,
#  1784248295122556685,
#  3471079116559308406,
#  4634025156594640239,
#  6363667696664616107,
#  693924950174409728,
#  6271041797853253252,
#  7730229831636583350,
#  5432804012465802402,
#  6326969040294904674,
#  557493158298586356,
#  3957908745626629806,
#  3635195553081907676,
#  3671113935005200698,
#  4309781359498384566,
#  5853179402261622109,
#  1523495559941338850,
# ...

# %%
timezone
# Out:
#                   store_id                  timezone_str
# 0      8139926242460185114                   Asia/Beirut
# 1      5415949628544298339                 America/Boise
# 2      3408529570017053440                America/Denver
# 3      9055649751952768824                America/Denver
# 4      4428372089193592098                America/Denver
# ...                    ...                           ...
# 13554  8281452819447825055  America/Indiana/Indianapolis
# 13555  8095410679721836114  America/Indiana/Indianapolis
# 13556  5588208013269746483  America/Indiana/Indianapolis
# 13557  7020170113785825189  America/Indiana/Indianapolis
# 13558  7869742085537243781  America/Indiana/Indianapolis
#
# [13559 rows x 2 columns]

# %%
timezone.dtypes
# Out:
# store_id         int64
# timezone_str    object
# dtype: object

# %%
timezone.shape
# Out:
# (13559, 2)

# %%
timezone.isnull().sum()
# Out:
# store_id        0
# timezone_str    0
# dtype: int64

# %%
distinct_count = timezone['store_id'].value_counts()
distinct_count
# Out:
# 678992977402804803     1
# 7030668286999776284    1
# 1709029171659478499    1
# 2879216131071724069    1
# 2621955219536925328    1
#                       ..
# 7159890699419266768    1
# 3458731922899831466    1
# 4860518410804234324    1
# 641950338567087803     1
# 207146620966629535     1
# Name: store_id, Length: 13559, dtype: int64

# %%
storID_Timezone = list(distinct_count.keys())
storID_Timezone
# Out:
# [678992977402804803,
#  7030668286999776284,
#  1709029171659478499,
#  2879216131071724069,
#  2621955219536925328,
#  5111481159829400869,
#  2836082899566291083,
#  2793102892543988097,
#  5618802221832925899,
#  1259520449529996861,
#  5638371070040836066,
#  882336681874281963,
#  8951425514201673913,
#  1997479607853560123,
#  5917085078996311930,
#  900977009264996690,
#  4243420246305474977,
#  3173733599679478576,
#  6130538156830304319,
#  3497567003580641425,
#  6418936212793536447,
#  364217790691395293,
#  7600006381746890516,
#  6441665535053935615,
#  4993098645975694261,
#  5219144433857983878,
#  495352612200987088,
#  5865498000145080860,
#  3719086539850211771,
#  6563641695966888897,
#  4769506793669078104,
#  7064982264177258193,
#  8596321227203123004,
#  5833493366658181332,
#  4334721460614182508,
#  8224150953804333994,
#  1241132482221307074,
#  4536632589623017319,
#  1383351499106565655,
#  6268587525648059116,
#  3326811774555178817,
# ...

# %%
ser1 = pd.Index(storID_Timezone)
ser2 = pd.Index(storID_Active)
ser3 = pd.Index(storID_Business)
intersect1 = list(ser1.intersection(ser2))
# print(intersect1)
ser4 = pd.Index(intersect1)
# print(intersect1)
# print(ser3)
# print(ser4)

# Int64Index(intersect, dtype='int64')
# 
intersect = ser3.intersection(ser4)
print(intersect)
# Out:
# Int64Index([ 778281888660867776, 5785297779221538030, 5301149089444945306,
#             1472400125885919118, 1176400014944170417, 3334248282862149533,
#             1600782661161589441, 6767755065226857745, 2983629168699704615,
#              152977603852070841,
#             ...
#             1213131748157718042, 5610284992872463884, 3547443835360588068,
#              104915753821730949, 3406213355646882913, 8453827384807852054,
#             7684223852601174802, 5711387831194927509, 5437414992872782794,
#             4520392672582664114],
#            dtype='int64', length=10996)

# %% [markdown]
# # get the store ID

# %%
storeID = 2964897505220625860

df_activeNew = active_data[active_data['store_id'] == storeID]
df_activeNew
# Out:
#                     store_id    status                   timestamp_utc
# 32590    2964897505220625860    active  2023-01-22 03:03:40.763773 UTC
# 151750   2964897505220625860    active  2023-01-22 07:05:01.025902 UTC
# 196110   2964897505220625860    active  2023-01-25 11:05:09.030805 UTC
# 332705   2964897505220625860    active  2023-01-22 12:01:24.637005 UTC
# 771000   2964897505220625860    active  2023-01-22 06:00:51.091389 UTC
# ...                      ...       ...                             ...
# 1797779  2964897505220625860  inactive  2023-01-19 01:45:55.396046 UTC
# 1799912  2964897505220625860  inactive  2023-01-24 11:01:02.433108 UTC
# 1811436  2964897505220625860  inactive  2023-01-19 19:42:46.087629 UTC
# 1812594  2964897505220625860  inactive  2023-01-19 09:58:43.034772 UTC
# 1816226  2964897505220625860  inactive  2023-01-20 14:01:04.002741 UTC
#
# [111 rows x 3 columns]

# %%
df_BusinessNew = business_hour[business_hour['store_id'] == storeID]
df_BusinessNew
# Out:
#                  store_id  day start_time_local end_time_local
# 8075  2964897505220625860    0         02:00:00       03:00:00

# %%
df_timezoneNew = timezone[timezone['store_id'] == storeID]
df_timezoneNew
# Out:
#                   store_id         timezone_str
# 12455  2964897505220625860  America/Los_Angeles

# %%
BusinessHrSt = (df_BusinessNew['start_time_local'])
BusinessHrEn = df_BusinessNew['end_time_local']

print(BusinessHrSt)
print(BusinessHrEn)
# Out:
# 8075    02:00:00
# Name: start_time_local, dtype: object
# 8075    03:00:00
# Name: end_time_local, dtype: object

# %%
BusinessHrSt = df_BusinessNew['start_time_local'][8075]
BusinessHrEn = df_BusinessNew['end_time_local'][8075]
print(BusinessHrSt)
print(BusinessHrEn)
# Out:
# 02:00:00
# 03:00:00

# %%
datetime_B = datetime.strptime(str(BusinessHrEn), '%H:%M:%S')
closinghr = datetime_B.hour
closingmin = datetime_B.minute
closingsec = datetime_B.second

# %%
datetime_B = datetime.strptime(str(BusinessHrSt), '%H:%M:%S')
openinghr = datetime_B.hour
openingmin = datetime_B.minute
openingsec = datetime_B.second
print(datetime_B.hour)
print(datetime_B.minute)
# Out:
# 2
# 0

# %%
time = df_activeNew['timestamp_utc'][151750]
time
# Out:
# '2023-01-22 07:05:01.025902 UTC'

# %%
stat = df_activeNew['status'][151750]
stat
# Out:
# 'active'

# %%
from datetime import datetime

timestamp_str = '2023-01-22 07:05:01.025902 UTC'
datetime_obj = datetime.strptime(timestamp_str, '%Y-%m-%d %H:%M:%S.%f %Z')
year = datetime_obj.year
month = datetime_obj.month
day = datetime_obj.day
hour = datetime_obj.hour
minute = datetime_obj.minute
second = datetime_obj.second

print(year)
print(month)
print(day)
print(hour)
print(minute)
print(second)
# Out:
# 2023
# 1
# 22
# 7
# 5
# 1

# %%
from datetime import datetime

datetime_obj = datetime.strptime(time, '%Y-%m-%d %H:%M:%S.%f %Z')
year = datetime_obj.year
month = datetime_obj.month
day = datetime_obj.day
hour = datetime_obj.hour
minute = datetime_obj.minute
second = datetime_obj.second

print(year)
print(month)
print(day)
print(hour)
print(minute)
print(second)
# Out:
# 2023
# 1
# 22
# 7
# 5
# 1

# %%
import csv
import json
 
 
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):
     
    # create a dictionary
    data = {}
     
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
         
        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:
             
            # Assuming a column named 'No' to
            # be the primary key
            key = rows['store_id']
            data[key] = rows
 
    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))
         
# Driver Code
 
# Decide the two file paths according to your
# computer system
csvFilePath = r'store status.csv'
jsonFilePath = r'Names.json'
 
# Call the make_json function
make_json(csvFilePath, jsonFilePath)

# %%
jsonFilePath
# Out:
# 'Names.json'

# %%
f = open('Names.json')
data = json.load(f)

data
# Out:
# {'8419537941919820732': {'store_id': '8419537941919820732',
#   'status': 'active',
#   'timestamp_utc': '2023-01-19 08:07:03.054056 UTC'},
#  '54515546588432327': {'store_id': '54515546588432327',
#   'status': 'active',
#   'timestamp_utc': '2023-01-24 23:10:56.308431 UTC'},
#  '8377465688456570187': {'store_id': '8377465688456570187',
#   'status': 'active',
#   'timestamp_utc': '2023-01-19 15:29:10.317346 UTC'},
#  '5955337179846162144': {'store_id': '5955337179846162144',
#   'status': 'active',
#   'timestamp_utc': '2023-01-21 15:05:04.442172 UTC'},
#  '1169347689335808384': {'store_id': '1169347689335808384',
#   'status': 'active',
#   'timestamp_utc': '2023-01-21 16:06:28.999115 UTC'},
#  '3739729523266121270': {'store_id': '3739729523266121270',
#   'status': 'active',
#   'timestamp_utc': '2023-01-24 16:08:38.016157 UTC'},
#  '4430370444829587327': {'store_id': '4430370444829587327',
#   'status': 'active',
#   'timestamp_utc': '2023-01-20 16:02:23.850552 UTC'},
# ...
